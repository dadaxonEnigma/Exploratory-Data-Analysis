# %%
import pandas as pd

# %%
df = pd.read_csv('zomato.csv', encoding='latin-1')

# %%
df.sample(5) # рандомные значение, что бы лучше видеть данные
# df.info()
df.columns.to_list()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
df.duplicated().sum() # полные дубли строк
df.duplicated(subset=['City']).sum()
# Out:
# 9410
